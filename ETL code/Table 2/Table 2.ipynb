# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy import Column, Integer, String, Float

from db_pw import password

import pandas as pd

Base = declarative_base()

# %%
database_path = "project2-pokedex"
engine = create_engine(f'postgresql://postgres:{password}@localhost/{database_path}')
conn = engine.connect()

session = Session(bind=engine)

# %%
Base.metadata.create_all(conn)

# %%
class Stats(Base):
    __tablename__ = 'STATS'
    name = Column(String, primary_key=True)
    baseStat = Column(Integer)
    healthPoints = Column(Integer)
    attack = Column(Integer)
    defense = Column(Integer)
    specialAttack = Column(Integer)
    specialDefense = Column(Integer)
    speed = Column(Integer)

# %%
test = Stats(name="Test", baseStat=1, healthPoints=1, attack=1, defense=1, specialAttack=1, specialDefense=1, speed=1)

# %%
#session.add(test)
#session.commit()
#session.rollback()

# %%
for stat in session.query(Stats):
    print(stat.baseStat)
# Out:
# 2
# 9

# %%
'''
Data Location
name = df_pokemon.csv - Name
baseStat = pokemon.csv - base_total OR df_pokemon.csv - Total
healthPoints = df_pokemon.csv - HP
attack = df_pokemon.csv - Attack
defense = df_pokemon.csv - Defense
specialAttack = df_pokemon.csv - Sp. Atk
specialDefense = df_pokemon.csv - Sp. Def
speed = df_pokemon.csv - Speed


'''
# Out:
# '\nData Location\nname = df_pokemon.csv - Name\nbaseStat = pokemon.csv - base_total\nhealthPoints = df_pokemon.csv - HP\nattack = df_pokemon.csv - Attack\ndefense = df_pokemon.csv - Defense\nspecialAttack = df_pokemon.csv - Sp. Atk\nspecialDefense = df_pokemon.csv - Sp. Def\nspeed = df_pokemon.csv - Speed\n\n\n'

# %%
df_pokemonCSV = pd.read_csv('../../resources/complete_pokemon_dataset/df_pokemon.csv')
pokemonCSV = pd.read_csv('../../resources/pokemon.csv')

print(df_pokemonCSV["Name"])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3              Mega Venusaur
# 4        Venusaur Gigantamax
#                 ...
# 1093               Glastrier
# 1094               Spectrier
# 1095                 Calyrex
# 1096    Calyrex Shadow Rider
# 1097       Calyrex Ice Rider
# Name: Name, Length: 1098, dtype: object

# %%
print(pokemonCSV.name[0])
# Out:
# Bulbasaur

# %%
df_pokemonCSV
# Out:
#        ID                  Name    Species       Variant  Generation  \
# 0       1             Bulbasaur  Bulbasaur           NaN           1
# 1       2               Ivysaur    Ivysaur           NaN           1
# 2       3              Venusaur   Venusaur           NaN           1
# 3       3         Mega Venusaur   Venusaur          Mega           6
# 4       3   Venusaur Gigantamax   Venusaur    Gigantamax           8
# ...   ...                   ...        ...           ...         ...
# 1093  896             Glastrier  Glastrier           NaN           8
# 1094  897             Spectrier  Spectrier           NaN           8
# 1095  898               Calyrex    Calyrex           NaN           8
# 1096  898  Calyrex Shadow Rider    Calyrex  Shadow Rider           8
# 1097  898     Calyrex Ice Rider    Calyrex     Ice Rider           8
#
#          Rarity Evolves_from Has_gender_diff    Type1   Type2  ...  Attack  \
# 0        Common          NaN           False    Grass  Poison  ...    49.0
# 1        Common    Bulbasaur           False    Grass  Poison  ...    62.0
# 2        Common      Ivysaur            True    Grass  Poison  ...    82.0
# 3        Common     Venusaur            True    Grass  Poison  ...   100.0
# 4           NaN     Venusaur             NaN    Grass  Poison  ...     NaN
# ...         ...          ...             ...      ...     ...  ...     ...
# 1093  Legendary          NaN           False      Ice     NaN  ...   145.0
# 1094  Legendary          NaN           False    Ghost     NaN  ...    65.0
# 1095  Legendary          NaN           False  Psychic   Grass  ...    80.0
# 1096  Legendary          NaN           False  Psychic   Ghost  ...    85.0
# 1097  Legendary          NaN           False  Psychic     Ice  ...   165.0
#
#       Defense  Sp. Atk  Sp. Def  Speed  \
# 0        49.0     65.0     65.0   45.0
# 1        63.0     80.0     80.0   60.0
# 2        83.0    100.0    100.0   80.0
# 3       123.0    122.0    120.0   80.0
# 4         NaN      NaN      NaN    NaN
# ...       ...      ...      ...    ...
# 1093    130.0     65.0    110.0   30.0
# 1094     60.0    145.0     80.0  130.0
# 1095     80.0     80.0     80.0   80.0
# 1096     80.0    165.0    100.0  150.0
# 1097    150.0     85.0    130.0   50.0
#
#                                               image_url  \
# 0     https://img.pokemondb.net/sprites/sword-shield...
# 1     https://img.pokemondb.net/sprites/sword-shield...
# 2     https://img.pokemondb.net/sprites/sword-shield...
# 3     https://img.pokemondb.net/sprites/sword-shield...
# 4     https://archives.bulbagarden.net/media/upload/...
# ...                                                 ...
# 1093  https://img.pokemondb.net/sprites/sword-shield...
# 1094  https://img.pokemondb.net/sprites/sword-shield...
# 1095  https://img.pokemondb.net/sprites/sword-shield...
# 1096  https://img.pokemondb.net/sprites/sword-shield...
# 1097  https://img.pokemondb.net/sprites/sword-shield...
#
#                                           VGC2022_rules Monthly Usage (k)  \
# 0                                             Permitted               NaN
# 1                                             Permitted               NaN
# 2                                             Permitted               204
# 3                                                Banned               NaN
# 4                                    Gigantamax Allowed               NaN
# ...                                                 ...               ...
# 1093                                          Permitted                13
# 1094                                          Permitted                19
# 1095  Restricted (players can include two Restricted...               NaN
# 1096                                                NaN               363
# 1097                                                NaN               294
#
#      Usage Percent (%) Monthly Rank
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                    7           24
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 1093                 0           86
# 1094                 1           61
# 1095               NaN          NaN
# 1096                22            8
# 1097                11           17
#
# [1098 rows x 22 columns]

# %%
statsDF = pd.DataFrame({
    "Name": df_pokemonCSV.Name, 
    "Base Stats": df_pokemonCSV.Total, 
    "HP": df_pokemonCSV.HP,
    "Attack": df_pokemonCSV.Attack,
    "Defense": df_pokemonCSV.Defense,
    "Special Attack": df_pokemonCSV["Sp. Atk"],
    "Special Defense": df_pokemonCSV["Sp. Def"],
    "Speed": df_pokemonCSV.Speed
})
statsDF
# Out:
#                       Name  Base Stats     HP  Attack  Defense  \
# 0                Bulbasaur       318.0   45.0    49.0     49.0
# 1                  Ivysaur       405.0   60.0    62.0     63.0
# 2                 Venusaur       525.0   80.0    82.0     83.0
# 3            Mega Venusaur       625.0   80.0   100.0    123.0
# 4      Venusaur Gigantamax         NaN    NaN     NaN      NaN
# ...                    ...         ...    ...     ...      ...
# 1093             Glastrier       580.0  100.0   145.0    130.0
# 1094             Spectrier       580.0  100.0    65.0     60.0
# 1095               Calyrex       500.0  100.0    80.0     80.0
# 1096  Calyrex Shadow Rider       680.0  100.0    85.0     80.0
# 1097     Calyrex Ice Rider       680.0  100.0   165.0    150.0
#
#       Special Attack  Special Defense  Speed
# 0               65.0             65.0   45.0
# 1               80.0             80.0   60.0
# 2              100.0            100.0   80.0
# 3              122.0            120.0   80.0
# 4                NaN              NaN    NaN
# ...              ...              ...    ...
# 1093            65.0            110.0   30.0
# 1094           145.0             80.0  130.0
# 1095            80.0             80.0   80.0
# 1096           165.0            100.0  150.0
# 1097            85.0            130.0   50.0
#
# [1098 rows x 8 columns]
