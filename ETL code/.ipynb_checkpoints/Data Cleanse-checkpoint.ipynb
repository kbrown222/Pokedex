# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy import Column, Integer, String, Float
import psycopg2

from db_pw import password

import pandas as pd

Base = declarative_base()

# %%
database_path = "project2-pokedex"
engine = create_engine(f'postgresql://postgres:{password}@localhost/{database_path}')
conn = engine.connect()

session = Session(bind=engine)

# %%
Base.metadata.create_all(conn)

# %%
'''
class Stats(Base):
    __tablename__ = 'STATS'
    name = Column(String, primary_key=True)
    baseStat = Column(Integer)
    healthPoints = Column(Integer)
    attack = Column(Integer)
    defense = Column(Integer)
    specialAttack = Column(Integer)
    specialDefense = Column(Integer)
    speed = Column(Integer)
'''

# %%
#test = Stats(name="Test", baseStat=1, healthPoints=1, attack=1, defense=1, specialAttack=1, specialDefense=1, speed=1)

# %%
#session.add(test)
#session.commit()
#session.rollback()

# %%
df_pokemonCSV = pd.read_csv('../resources/df_pokemon.csv')
pokemonCSV = pd.read_csv('../resources/pokemon.csv')
smogonCSV = pd.read_csv('../resources/smogon.csv')
bridgeAbilityCSV = pd.read_csv('../resources/bridge_pokemon_ability_MAY_HAS.csv')
bridgeMoveUsedCSV = pd.read_csv('../resources/bridge_pokemon_move_USED_WITH_MOVE.csv')
bridgeMovesMayLearnCSV = pd.read_csv('../resources/bridge_pokemon_moves_MAY_LEARN.csv')

# %%
df_pokemonCSV

# %%
# Table 1
# pokemonCSV

pokedexDF = pd.DataFrame({
    "nationalDexNumber": pokemonCSV['pokedex_number'],
    "name": pokemonCSV['name'],
    "description": pokemonCSV['classfication'],
    "weight": pokemonCSV['weight_kg'].fillna(0.0),
    "height": pokemonCSV['height_m'],
    "type1": pokemonCSV['type1'],
    "type2": pokemonCSV['type2'].fillna('-'),
    "evolvesFrom": ""
})

pokedexDF = pokedexDF.set_index(['nationalDexNumber'])

pokedexDF.head(50)
# Out:
#                          name          description  weight  height     type1  \
# nationalDexNumber
# 1                   Bulbasaur         Seed Pokémon     6.9     0.7     grass
# 2                     Ivysaur         Seed Pokémon    13.0     1.0     grass
# 3                    Venusaur         Seed Pokémon   100.0     2.0     grass
# 4                  Charmander       Lizard Pokémon     8.5     0.6      fire
# 5                  Charmeleon        Flame Pokémon    19.0     1.1      fire
# 6                   Charizard        Flame Pokémon    90.5     1.7      fire
# 7                    Squirtle  Tiny Turtle Pokémon     9.0     0.5     water
# 8                   Wartortle       Turtle Pokémon    22.5     1.0     water
# 9                   Blastoise    Shellfish Pokémon    85.5     1.6     water
# 10                   Caterpie         Worm Pokémon     2.9     0.3       bug
# 11                    Metapod       Cocoon Pokémon     9.9     0.7       bug
# 12                 Butterfree    Butterfly Pokémon    32.0     1.1       bug
# 13                     Weedle        Hairy Pokémon     3.2     0.3       bug
# 14                     Kakuna       Cocoon Pokémon    10.0     0.6       bug
# 15                   Beedrill   Poison Bee Pokémon    29.5     1.0       bug
# 16                     Pidgey    Tiny Bird Pokémon     1.8     0.3    normal
# 17                  Pidgeotto         Bird Pokémon    30.0     1.1    normal
# 18                    Pidgeot         Bird Pokémon    39.5     1.5    normal
# 19                    Rattata        Mouse Pokémon     0.0     NaN    normal
# 20                   Raticate        Mouse Pokémon     0.0     NaN    normal
# 21                    Spearow    Tiny Bird Pokémon     2.0     0.3    normal
# 22                     Fearow         Beak Pokémon    38.0     1.2    normal
# 23                      Ekans        Snake Pokémon     6.9     2.0    poison
# 24                      Arbok        Cobra Pokémon    65.0     3.5    poison
# 25                    Pikachu        Mouse Pokémon     6.0     0.4  electric
# 26                     Raichu        Mouse Pokémon     0.0     NaN  electric
# 27                  Sandshrew        Mouse Pokémon     0.0     NaN    ground
# 28                  Sandslash        Mouse Pokémon     0.0     NaN    ground
# 29                   Nidoran♀   Poison Pin Pokémon     7.0     0.4    poison
# 30                   Nidorina   Poison Pin Pokémon    20.0     0.8    poison
# 31                  Nidoqueen        Drill Pokémon    60.0     1.3    poison
# 32                   Nidoran♂   Poison Pin Pokémon     9.0     0.5    poison
# 33                   Nidorino   Poison Pin Pokémon    19.5     0.9    poison
# 34                   Nidoking        Drill Pokémon    62.0     1.4    poison
# 35                   Clefairy        Fairy Pokémon     7.5     0.6     fairy
# 36                   Clefable        Fairy Pokémon    40.0     1.3     fairy
# 37                     Vulpix          Fox Pokémon     0.0     NaN      fire
# 38                  Ninetales          Fox Pokémon     0.0     NaN      fire
# 39                 Jigglypuff      Balloon Pokémon     5.5     0.5    normal
# 40                 Wigglytuff      Balloon Pokémon    12.0     1.0    normal
# 41                      Zubat          Bat Pokémon     7.5     0.8    poison
# 42                     Golbat          Bat Pokémon    55.0     1.6    poison
# 43                     Oddish         Weed Pokémon     5.4     0.5     grass
# 44                      Gloom         Weed Pokémon     8.6     0.8     grass
# 45                  Vileplume       Flower Pokémon    18.6     1.2     grass
# 46                      Paras     Mushroom Pokémon     5.4     0.3       bug
# 47                   Parasect     Mushroom Pokémon    29.5     1.0       bug
# 48                    Venonat       Insect Pokémon    30.0     1.0       bug
# 49                   Venomoth  Poison Moth Pokémon    12.5     1.5       bug
# 50                    Diglett         Mole Pokémon     0.0     NaN    ground
#
#                       type2 evolvesFrom
# nationalDexNumber
# 1                    poison
# 2                    poison
# 3                    poison
# 4                         -
# 5                         -
# 6                    flying
# 7                         -
# 8                         -
# 9                         -
# 10                        -
# 11                        -
# 12                   flying
# 13                   poison
# 14                   poison
# 15                   poison
# 16                   flying
# 17                   flying
# 18                   flying
# 19                     dark
# 20                     dark
# 21                   flying
# 22                   flying
# 23                        -
# 24                        -
# 25                        -
# 26                 electric
# 27                      ice
# 28                      ice
# 29                        -
# 30                        -
# 31                   ground
# 32                        -
# 33                        -
# 34                   ground
# 35                        -
# 36                        -
# 37                      ice
# 38                      ice
# 39                    fairy
# 40                    fairy
# 41                   flying
# 42                   flying
# 43                   poison
# 44                   poison
# 45                   poison
# 46                    grass
# 47                    grass
# 48                   poison
# 49                   poison
# 50                   ground

# %%
df_pokemonCSV_new = df_pokemonCSV.fillna('-')
#df_pokemonCSV = df_pokemonCSV.set_index(['ID'])

for index,pokemon in df_pokemonCSV.iterrows():
    if pokemon.Evolves_from == '-':
        print("NULL")
    else:
        print(f"{index} - {pokemon.Evolves_from}")

# %%
pokedexDF.loc[:, ['name', 'evolvesFrom']]
pokedexDF.loc[1,'name']
#df_pokemonCSV_new.loc[1, 'Name']
# df_pokemonCSV_new.loc[index,'Evolves_from']
df_pokemonCSV

# %%
for index, pokemonDF in pokedexDF.iterrows():
    try:
        pokedexDF.at[index,'evolvesFrom'] = df_pokemonCSV['Evolves_from'].loc[(df_pokemonCSV['Name'] == pokemonDF['name'])].values[0]
    except:
        pokedexDF.at[index,'evolvesFrom'] = '-'
    #print(f"{pokemonDF['name']} - {df_pokemonCSV['Evolves_from'].loc[(df_pokemonCSV['Name'] == pokemonDF['name'])].values[0]}")
    
#pokedexDF = pokedexDF.fillna('-')

# %%
pokedexDF.dtypes
# Out:
# name            object
# description     object
# weight         float64
# height         float64
# type1           object
# type2           object
# evolvesFrom     object
# dtype: object

# %%
pokedexDF.head(20)
# Out:
#                          name          description  weight  height   type1  \
# nationalDexNumber
# 1                   Bulbasaur         Seed Pokémon     6.9     0.7   grass
# 2                     Ivysaur         Seed Pokémon    13.0     1.0   grass
# 3                    Venusaur         Seed Pokémon   100.0     2.0   grass
# 4                  Charmander       Lizard Pokémon     8.5     0.6    fire
# 5                  Charmeleon        Flame Pokémon    19.0     1.1    fire
# 6                   Charizard        Flame Pokémon    90.5     1.7    fire
# 7                    Squirtle  Tiny Turtle Pokémon     9.0     0.5   water
# 8                   Wartortle       Turtle Pokémon    22.5     1.0   water
# 9                   Blastoise    Shellfish Pokémon    85.5     1.6   water
# 10                   Caterpie         Worm Pokémon     2.9     0.3     bug
# 11                    Metapod       Cocoon Pokémon     9.9     0.7     bug
# 12                 Butterfree    Butterfly Pokémon    32.0     1.1     bug
# 13                     Weedle        Hairy Pokémon     3.2     0.3     bug
# 14                     Kakuna       Cocoon Pokémon    10.0     0.6     bug
# 15                   Beedrill   Poison Bee Pokémon    29.5     1.0     bug
# 16                     Pidgey    Tiny Bird Pokémon     1.8     0.3  normal
# 17                  Pidgeotto         Bird Pokémon    30.0     1.1  normal
# 18                    Pidgeot         Bird Pokémon    39.5     1.5  normal
# 19                    Rattata        Mouse Pokémon     0.0     NaN  normal
# 20                   Raticate        Mouse Pokémon     0.0     NaN  normal
#
#                     type2 evolvesFrom
# nationalDexNumber
# 1                  poison         NaN
# 2                  poison   Bulbasaur
# 3                  poison     Ivysaur
# 4                       -         NaN
# 5                       -  Charmander
# 6                  flying  Charmeleon
# 7                       -         NaN
# 8                       -    Squirtle
# 9                       -   Wartortle
# 10                      -         NaN
# 11                      -    Caterpie
# 12                 flying     Metapod
# 13                 poison         NaN
# 14                 poison      Weedle
# 15                 poison      Kakuna
# 16                 flying         NaN
# 17                 flying      Pidgey
# 18                 flying   Pidgeotto
# 19                   dark         NaN
# 20                   dark     Rattata

# %% [markdown]
# ## Table 1 complete, loading it to postgres

# %% [markdown]
# database_path = "project2-pokedex"
# engine = create_engine(f'postgresql://postgres:{password}@localhost/{database_path}')
# conn = engine.connect()
#
# session = Session(bind=engine)

# %% [markdown]
# database_path = "project2-pokedex"
# conn_string = 'postgresql://postgres:{password}@localhost/{database_path}'
#
# db = create_engine(conn_string)
# conn = db.connect()
# conn1 = psycopg2.connect(
#     database = "

# %%
#pokedexDF.to_sql('POKEDEX', engine, if_exists='append')
# Out:
# '\n## Prior code above ##\ndbName = "project2-pokedex"\n\npokedexDF.to_sql(\'POKEDEX\', con = engine , if_exists=\'replace\',\n         index=False)\nconn = psycopg2.connect(f"postgresql://postgres:{password}@localhost/{database_path}")\n\nconn.autocommit = True\ncursor = conn.cursor()\n'

# %%
#session.close()

# %% [markdown]
# # Table 2 transformations

# %%
df_pokemonCSV

# %%
# Table 2
statsDF = pd.DataFrame({
    "nationalDexNumber": df_pokemonCSV.ID,
    "name": df_pokemonCSV.Name, 
    "baseStat": df_pokemonCSV.Total, 
    "healthPoints": df_pokemonCSV.HP,
    "attack": df_pokemonCSV.Attack,
    "defense": df_pokemonCSV.Defense,
    "specialAttack": df_pokemonCSV["Sp. Atk"],
    "specialDefense": df_pokemonCSV["Sp. Def"],
    "speed": df_pokemonCSV.Speed
})
statsDF = statsDF.dropna()
statsDF['baseStat'] = statsDF['baseStat'].astype('int32')
statsDF['healthPoints'] = statsDF['healthPoints'].astype('int32')
statsDF['attack'] = statsDF['attack'].astype('int32')
statsDF['defense'] = statsDF['defense'].astype('int32')
statsDF['specialAttack'] = statsDF['specialAttack'].astype('int32')
statsDF['specialDefense'] = statsDF['specialDefense'].astype('int32')
statsDF['speed'] = statsDF['speed'].astype('int32')

statsDF
# Out:
#       nationalDexNumber                  name  baseStat  healthPoints  attack  \
# 0                     1             Bulbasaur       318            45      49
# 1                     2               Ivysaur       405            60      62
# 2                     3              Venusaur       525            80      82
# 3                     3         Mega Venusaur       625            80     100
# 5                     4            Charmander       309            39      52
# ...                 ...                   ...       ...           ...     ...
# 1093                896             Glastrier       580           100     145
# 1094                897             Spectrier       580           100      65
# 1095                898               Calyrex       500           100      80
# 1096                898  Calyrex Shadow Rider       680           100      85
# 1097                898     Calyrex Ice Rider       680           100     165
#
#       defense  specialAttack  specialDefense  speed
# 0          49             65              65     45
# 1          63             80              80     60
# 2          83            100             100     80
# 3         123            122             120     80
# 5          43             60              50     65
# ...       ...            ...             ...    ...
# 1093      130             65             110     30
# 1094       60            145              80    130
# 1095       80             80              80     80
# 1096       80            165             100    150
# 1097      150             85             130     50
#
# [1066 rows x 9 columns]

# %%
statsDF_corrected = statsDF.loc[statsDF["nationalDexNumber"] < 802]
statsDF_corrected = statsDF_corrected.set_index(['nationalDexNumber'])

statsDF_corrected
# Out:
#                                   name  baseStat  healthPoints  attack  \
# nationalDexNumber
# 1                            Bulbasaur       318            45      49
# 2                              Ivysaur       405            60      62
# 3                             Venusaur       525            80      82
# 3                        Mega Venusaur       625            80     100
# 4                           Charmander       309            39      52
# ...                                ...       ...           ...     ...
# 800                 Dusk Mane Necrozma       680            97     157
# 800                           Necrozma       600            97     107
# 800                Dawn Wings Necrozma       680            97     113
# 800                     Ultra Necrozma       754            97     167
# 801                           Magearna       600            80      95
#
#                    defense  specialAttack  specialDefense  speed
# nationalDexNumber
# 1                       49             65              65     45
# 2                       63             80              80     60
# 3                       83            100             100     80
# 3                      123            122             120     80
# 4                       43             60              50     65
# ...                    ...            ...             ...    ...
# 800                    127            113             109     77
# 800                    101            127              89     79
# 800                    109            157             127     77
# 800                     97            167              97    129
# 801                    115            130             115     65
#
# [959 rows x 8 columns]

# %%
#statsDF_corrected.to_sql('STATS', engine, if_exists='append')
# Out:
# 959

# %%
# Table 3
#abilityDF = pd.DataFrame({
#    "name": pokedexDF.name
#})
#
#abilityDF
# Out:
#                          name
# nationalDexNumber
# 1                   Bulbasaur
# 2                     Ivysaur
# 3                    Venusaur
# 4                  Charmander
# 5                  Charmeleon
# ...                       ...
# 797                Celesteela
# 798                   Kartana
# 799                  Guzzlord
# 800                  Necrozma
# 801                  Magearna
#
# [801 rows x 1 columns]

# %%
#abilityDF.to_sql('ABILITIES', engine, if_exists='append')
# Out:
# 801

# %%
# Table 4
# heldItemsDF =
